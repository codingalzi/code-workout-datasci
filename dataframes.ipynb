# %% [markdown]
# # 판다스 데이터프레임

# %% [markdown]
# 아래 엑셀 파일의 표<font size='2'>table</font> 형식으로 제공되는
# 2차원 데이터를 효율적으로 처리하는 판다스 데이터프레임 자료형을 간단히 소개한다.
# 데이터프레임의 다양한 기능은 확률과 통계의 기초를 다루면서 하나씩 활용할 예정이다.
#
# <div align="center">
#     <img src="https://raw.githubusercontent.com/codingalzi/datapy/master/jupyter-book/images/excel-fruits.png" width="450">
# </div>

# %% [markdown]
# **기본 설정**

# %% [markdown]
# `numpy`와 `pandas` 라이브러리를 각각 `np`와 `pd`로 불러온다.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **데이터셋 저장소**

# %%
data_url = 'https://raw.githubusercontent.com/codingalzi/code-workout-datasci/refs/heads/master/data/'

# %% [markdown]
# ## 데이터프레임 생성

# %% [markdown]
# **데이터프레임**<font size='2'>DataFrame</font>은 인덱스를 공유하는 여러 개의 시리즈가
# 결합된 2차원 데이터구조다.

# %% [markdown]
# **`pd.concat()` 함수 활용**

# %% [markdown]
# `pd.concat()` 함수는 여러 개의 시리즈 또는 데이터프레임을 묶어 하나의 데이터프레임을 생성한다.
# 묶는 방식은 축을 지정함으로써 결정되는데,
# 옆으로 묶으려면 열 단위로 추가한다는 뜻으로 `axis=1`을 설정하면 된다.
# 추가되는 각 열의 이름은 시리즈에 저장된 `name` 속성으로 지정된다.

# %%
series1 = pd.Series([4, 5, 6, 3, 1], name="Mango")
series2 = pd.Series([5, 4, 3, 0, 2], name="Apple")
series3 = pd.Series([2, 3, 5, 2, 7], name="Banana")

fruits1 = pd.concat([series1, series2, series3], axis=1)
fruits1
# Out:
#    Mango  Apple  Banana
# 0      4      5       2
# 1      5      4       3
# 2      6      3       5
# 3      3      0       2
# 4      1      2       7

# %% [markdown]
# 자료형은 `pd.DataFrame`이다.

# %%
type(fruits1)
# Out:
# pandas.DataFrame

# %% [markdown]
# 각 시리즈의 행 인덱스를 지정하지 않았기에
# 0부터 시작하는 정수 인덱스가 행 인덱스로 사용되며,
# 시리즈의 경우처럼 `RangeIndex` 객체가 데이터프레임의 `index` 속성에 저장된다.

# %%
fruits1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# **넘파이 2차원 어레이 활용**

# %% [markdown]
# 넘파이 2차원 어레이를 이용하여 데이터프레임을 생성할 수 있다.
# 망고, 사과, 바나나 데이터를 담고 있는 아래 어레이를 이용하여 이전과
# 동일한 데이터프레임을 생성할 수 있다.

# %%
fruits_array = np.array([[4, 5, 2],
                         [5, 4, 3],
                         [6, 3, 5],
                         [3, 0, 2],
                         [1, 2, 7]])

# %% [markdown]
# 데이터프레임 객체를 생성할 때 어레이를 생성자의 인자로 지정하면 된다.
# 또한 각 열의 이름을 담은 리스트를 `columns`의 키워드 인자로 지정한다.

# %%
fruits1= pd.DataFrame(fruits_array,
                     columns=['Mango', 'Apple', 'Banana'])
fruits1
# Out:
#    Mango  Apple  Banana
# 0      4      5       2
# 1      5      4       3
# 2      6      3       5
# 3      3      0       2
# 4      1      2       7

# %% [markdown]
# 데이터프레임의 열별 이름을 **열 인덱스**라고 부르며,
# `columns` 속성에 `Index` 객체로 저장된다.

# %%
fruits1.columns
# Out:
# Index(['Mango', 'Apple', 'Banana'], dtype='str')

# %% [markdown]
# 시리즈 객체를 생성할 때처럼 행 인덱스를 지정하면서 데이터프레임 객체를 생성할 수 있다.
# 아래 코드는 A부터 E까지의 영어 대문자 알파벳을 행 인덱스로 지정한다.

# %%
fruits1= pd.DataFrame(fruits_array,
                     columns=['Mango', 'Apple', 'Banana'],
                     index=['A', 'B', 'C', 'D', 'E'])
fruits1
# Out:
#    Mango  Apple  Banana
# A      4      5       2
# B      5      4       3
# C      6      3       5
# D      3      0       2
# E      1      2       7

# %% [markdown]
# 행 인덱스를 별도로 지정하였기에 시리즈의 경우처럼
# 라벨 `Index` 객체가 행 인덱스 객체로 지정된다.

# %%
fruits1.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='str')

# %% [markdown]
# **사전 활용**

# %% [markdown]
# 열 이름을 키<font size='2'>key</font>로,
# 리스트를 키의 값<font size='2'>value</font>으로 갖는 사전을 이용해 데이터프레임을 생성할 수 있다.
# 이때 모든 리스트의 길이가 동일해야 한다.
#
# 아래 코드에서 `fruits_dict`는 `Mango`, `Apple`, `Banana`를 키로,
# 각각의 키에 할당된 리스트를 갖는 사전을 정의한다.

# %%
fruits_dict = {'Mango': [4, 5, 6, 3, 1],
               'Apple': [5, 4, 3, 0, 2],
               'Banana': [2, 3, 5, 2, 7]}

# %% [markdown]
# 위 사전 객체를 데이터프레임으로 변환하면 다음과 같으며,
# 사전에 사용된 키가 열 인덱스로 자동 지정된다.

# %%
fruits1 = pd.DataFrame(fruits_dict)
fruits1
# Out:
#    Mango  Apple  Banana
# 0      4      5       2
# 1      5      4       3
# 2      6      3       5
# 3      3      0       2
# 4      1      2       7

# %% [markdown]
# 위 코드에서 행 인덱스를 별도로 지정하지 않았기에 이 경우에도
# `RangeIndex` 인덱스 객체가 행 인덱스 객체로 지정된다.

# %%
fruits1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# **CSV 파일 활용**

# %% [markdown]
# 아래 코드는 피어슨 아버지-아들 키 데이터셋을 데이터프레임으로 불러온다.
# CSV 파일에 헤더를 지정하면 각 열의 라벨로 함께 불러온다.

# %%
pearson_df = pd.read_csv(data_url+"pearson_dataset.csv", header=0)
pearson_df
# Out:
#       Father    Son
# 0      165.1  151.9
# 1      160.8  160.5
# 2      165.1  160.8
# 3      167.1  159.5
# 4      155.2  163.3
# ...      ...    ...
# 1073   170.2  179.8
# 1074   181.1  173.5
# 1075   182.4  176.0
# 1076   179.6  176.0
# 1077   178.6  170.2
#
# [1078 rows x 2 columns]

# %% [markdown]
# **`DatetimeIndex` 활용**

# %% [markdown]
# `pd.date_range()` 함수는 규칙적인 간격의 날짜와 시간으로 구성된 인덱스 자료형을 생성한다.
# 아래 함수 호출에 사용된 키워드 인자의 의미는 다음과 같다.
#
# - `start="20260301"`: 2026년 3월 1일부터 시작
# - `periods=5`: 첫째 인자로 지정된 시간부터 5 개의 시간 데이터 샘플 생성
# - `freq="D"`: 간격은 일(Day) 단위로 지정

# %%
dates = pd.date_range(start="20260301", periods=5, freq="D")
dates
# Out:
# DatetimeIndex(['2026-03-01', '2026-03-02', '2026-03-03', '2026-03-04',
#                '2026-03-05'],
#               dtype='datetime64[us]', freq='D')

# %% [markdown]
# 데이터분석에서 `DatetimeIndex` 객체를 행 인덱스로의 활용은 빈번히 발생한다.
# 아래 코드는 행 인덱스를 앞서 정의 한 `dates`가 가리키는 시간 객체로 지정한다.
# 그러면 마치 날짜별 과일 재고량 또는 판매량을 담은 데이터셋으로 해석될 수 있게 된다.

# %%
fruits_date = pd.DataFrame(fruits_dict, index=dates)
fruits_date
# Out:
#             Mango  Apple  Banana
# 2026-03-01      4      5       2
# 2026-03-02      5      4       3
# 2026-03-03      6      3       5
# 2026-03-04      3      0       2
# 2026-03-05      1      2       7

# %% [markdown]
# :::{note} `freq` 속성값
# `dates`에 할당할 `DatetimeIndex` 객체를 정의할 때 사용된 `freq` 매개변수는
# 생성되는 시간들의 간격 또는 주기를 지정한다.
# `freq` 매개변수의 키워드 인자로 `'D'`(일 단위)와 `'h'`(시 단위) 이외에 다수의 문자열이
# 지정될 수 있다.
# 보다 자세한 내용은
# [(판다스 공식문서) Time series#Offset aliases](https://pandas.pydata.org/docs/user_guide/timeseries.html#offset-aliases)를 참고한다.
# :::

# %% [markdown]
# ### 연습문제

# %% [markdown]
# (1) 아래 코드는 2026년 3월 1일 0시부터 1시간 단위로 변하는 48개,
# 즉 이틀 동안의 시간 데이터로 구성된 `DatetimeIndex` 객체를 활용한다.

# %%
two_days = pd.date_range(start="20260301", periods=48, freq="h")
two_days
# Out:
# DatetimeIndex(['2026-03-01 00:00:00', '2026-03-01 01:00:00',
#                '2026-03-01 02:00:00', '2026-03-01 03:00:00',
#                '2026-03-01 04:00:00', '2026-03-01 05:00:00',
#                '2026-03-01 06:00:00', '2026-03-01 07:00:00',
#                '2026-03-01 08:00:00', '2026-03-01 09:00:00',
#                '2026-03-01 10:00:00', '2026-03-01 11:00:00',
#                '2026-03-01 12:00:00', '2026-03-01 13:00:00',
#                '2026-03-01 14:00:00', '2026-03-01 15:00:00',
#                '2026-03-01 16:00:00', '2026-03-01 17:00:00',
#                '2026-03-01 18:00:00', '2026-03-01 19:00:00',
#                '2026-03-01 20:00:00', '2026-03-01 21:00:00',
#                '2026-03-01 22:00:00', '2026-03-01 23:00:00',
#                '2026-03-02 00:00:00', '2026-03-02 01:00:00',
#                '2026-03-02 02:00:00', '2026-03-02 03:00:00',
#                '2026-03-02 04:00:00', '2026-03-02 05:00:00',
# ...

# %% [markdown]
# 가. `DatetimeIndex` 클래스는 `Index` 클래스의 자식 클래스며,
# `Index` 객체는 인덱싱과 슬라이싱을 지원한다.
# `two_days`가 가리키는 `DatetimeIndex` 객체에 포함된 0번과 24번 인덱스의 값을 확인하라.

# %% [markdown]
# 답:

# %% [markdown]
# 리스트 인덱싱처럼 적용하면 되며,
# `Timestamp` 자료형의 객체가 생성된다.

# %% [markdown]
# - 0번 인덱스: 2026년 3월 1일 0시

# %%
two_days[0]
# Out:
# Timestamp('2026-03-01 00:00:00')

# %% [markdown]
# - 24번 인덱스: 2026년 3월 2일 0시

# %%
two_days[24]
# Out:
# Timestamp('2026-03-02 00:00:00')

# %% [markdown]
# :::{note} `pd.Timestamp` 클래스
#
# [`pd.Timestamp` 클래스](https://pandas.pydata.org/docs/reference/api/pandas.Timestamp.html)는 날짜 형식의 데이터를 처리하는 다양한 기능을 제공한다.
# 앞으로 필요할 때마다 하나씩 기능을 소개할 것이다.
# :::

# %% [markdown]
# 나. 정수 인덱스로 구성된 리스트를 사용하면
# 리스트에 포함된 인덱스에 해당하는 시간으로 구성된 `DatetimeIndex` 객체가 생성된다.
#
# 0번과 24번 인덱스의 시간으로 구성된 `DatetimeIndex` 객체를 생성하라.

# %% [markdown]
# 답:

# %% [markdown]
# `[0, 24]`를 인덱싱에 활용한다.

# %%
two_days[[0, 24]]
# Out:
# DatetimeIndex(['2026-03-01', '2026-03-02'], dtype='datetime64[us]', freq=None)

# %% [markdown]
# 이처럼 리스트를 활용한 인덱싱을 **팬시 인덱싱**이라 부른다.
# 이후 데이터프레임 인덱싱을 설명할 때 보다 자세히 다룬다.

# %% [markdown]
# 다. 2026년 3월 2일 0시부터 3월 2일 오전 11시까지의 시간을 담은 `DatetimeIndex` 객체를 생성하라.

# %% [markdown]
# 답:

# %% [markdown]
# 3월 2일 0시는 24번 인덱스, 3월 2일 오전 11는 35번 인덱스에
# 위치하기에 다음과 같이 슬라이싱을 적용한다.

# %%
two_days[24:36]
# Out:
# DatetimeIndex(['2026-03-02 00:00:00', '2026-03-02 01:00:00',
#                '2026-03-02 02:00:00', '2026-03-02 03:00:00',
#                '2026-03-02 04:00:00', '2026-03-02 05:00:00',
#                '2026-03-02 06:00:00', '2026-03-02 07:00:00',
#                '2026-03-02 08:00:00', '2026-03-02 09:00:00',
#                '2026-03-02 10:00:00', '2026-03-02 11:00:00'],
#               dtype='datetime64[us]', freq='h')

# %% [markdown]
# (2) `pd.date_range()` 함수를 활용하는 문제다.
#
# 가. `one_day` 변수가 2026년 4월 1일 0시부터 밤 11시까지,
# 총 24개의 시간으로 구성된 `DatetimeIndex` 객체를 가리키도록 하라.

# %% [markdown]
# 답:

# %% [markdown]
# `pd.date_range()` 함수를 이용한다.

# %%
one_day = pd.date_range(start="20260401", periods=24, freq="h")
one_day
# Out:
# DatetimeIndex(['2026-04-01 00:00:00', '2026-04-01 01:00:00',
#                '2026-04-01 02:00:00', '2026-04-01 03:00:00',
#                '2026-04-01 04:00:00', '2026-04-01 05:00:00',
#                '2026-04-01 06:00:00', '2026-04-01 07:00:00',
#                '2026-04-01 08:00:00', '2026-04-01 09:00:00',
#                '2026-04-01 10:00:00', '2026-04-01 11:00:00',
#                '2026-04-01 12:00:00', '2026-04-01 13:00:00',
#                '2026-04-01 14:00:00', '2026-04-01 15:00:00',
#                '2026-04-01 16:00:00', '2026-04-01 17:00:00',
#                '2026-04-01 18:00:00', '2026-04-01 19:00:00',
#                '2026-04-01 20:00:00', '2026-04-01 21:00:00',
#                '2026-04-01 22:00:00', '2026-04-01 23:00:00'],
#               dtype='datetime64[us]', freq='h')

# %% [markdown]
# 나. `one_day`를 열 인덱스(columns)로 사용하여 `(2, 24)` 모양의 데이터프레임을 생성하라.
# 단, 행 인덱스는 `['온도', '습도']`로, 항목은 `np.arange()` 함수를 활용하여 0부터 시작하는 정수로 채운다.

# %% [markdown]
# 답:

# %% [markdown]
# `one_day`는 길이가 24인 `DatetimeIndex` 객체이므로 24개의 열을 갖는 데이터프레임의 열 인덱스로 활용할 수 있다.
# 항목은 `np.arange(48)`으로 생성한 뒤 `reshape(2, 24)`로 모양을 변경한다.

# %%
weather_df = pd.DataFrame(np.arange(48).reshape(2, 24),
                          index=['온도', '습도'],
                          columns=one_day)
weather_df
# Out:
#     2026-04-01 00:00:00  2026-04-01 01:00:00  2026-04-01 02:00:00  \
# 온도                    0                    1                    2
# 습도                   24                   25                   26
#
#     2026-04-01 03:00:00  2026-04-01 04:00:00  2026-04-01 05:00:00  \
# 온도                    3                    4                    5
# 습도                   27                   28                   29
#
#     2026-04-01 06:00:00  2026-04-01 07:00:00  2026-04-01 08:00:00  \
# 온도                    6                    7                    8
# 습도                   30                   31                   32
#
#     2026-04-01 09:00:00  ...  2026-04-01 14:00:00  2026-04-01 15:00:00  \
# 온도                    9  ...                   14                   15
# 습도                   33  ...                   38                   39
#
#     2026-04-01 16:00:00  2026-04-01 17:00:00  2026-04-01 18:00:00  \
# 온도                   16                   17                   18
# ...

# %% [markdown]
# 다. `one_day`를 행 인덱스로 사용하여 `(24, 2)` 모양의 데이터프레임을 생성하라.
# 단, 열 인덱스는 `['온도', '습도']`로, 항목은 `np.arange()` 함수를 활용하여 0부터 시작하는 정수로 채운다.

# %% [markdown]
# 답:

# %% [markdown]
# `one_day`는 길이가 24인 `DatetimeIndex` 객체이므로 24개의 행을 갖는 데이터프레임의 행 인덱스로 활용할 수 있다.
# 항목은 `np.arange(48)`으로 생성한 뒤 `reshape(24, 2)`로 모양을 변경한다.

# %%
weather_df = pd.DataFrame(np.arange(48).reshape(24, 2),
                          columns=['온도', '습도'],
                          index=one_day)
weather_df
# Out:
#                      온도  습도
# 2026-04-01 00:00:00   0   1
# 2026-04-01 01:00:00   2   3
# 2026-04-01 02:00:00   4   5
# 2026-04-01 03:00:00   6   7
# 2026-04-01 04:00:00   8   9
# 2026-04-01 05:00:00  10  11
# 2026-04-01 06:00:00  12  13
# 2026-04-01 07:00:00  14  15
# 2026-04-01 08:00:00  16  17
# 2026-04-01 09:00:00  18  19
# 2026-04-01 10:00:00  20  21
# 2026-04-01 11:00:00  22  23
# 2026-04-01 12:00:00  24  25
# 2026-04-01 13:00:00  26  27
# 2026-04-01 14:00:00  28  29
# 2026-04-01 15:00:00  30  31
# 2026-04-01 16:00:00  32  33
# 2026-04-01 17:00:00  34  35
# 2026-04-01 18:00:00  36  37
# 2026-04-01 19:00:00  38  39
# 2026-04-01 20:00:00  40  41
# 2026-04-01 21:00:00  42  43
# 2026-04-01 22:00:00  44  45
# 2026-04-01 23:00:00  46  47

# %% [markdown]
# (3) 아래 코드는 피어슨 아버지-아들 키 데이터셋에서 아들 키 데이터만 데이터프레임으로 불러온다.
# CSV 파일에 헤더를 지정하면 지정된 열의 라벨로 함께 불러온다.

# %%
sons_df = pd.read_csv(data_url+"pearson_dataset.csv", header=0, usecols=[1])
sons_df
# Out:
#         Son
# 0     151.9
# 1     160.5
# 2     160.8
# 3     159.5
# 4     163.3
# ...     ...
# 1073  179.8
# 1074  173.5
# 1075  176.0
# 1076  176.0
# 1077  170.2
#
# [1078 rows x 1 columns]

# %% [markdown]
# 헤더에 포함된 열의 이름으로 구성된 리스트를 `usecols`의 키워드 인자로 지정해서 불러와도 된다.

# %%
sons_df = pd.read_csv(data_url+"pearson_dataset.csv", header=0, usecols=['Son'])
sons_df
# Out:
#         Son
# 0     151.9
# 1     160.5
# 2     160.8
# 3     159.5
# 4     163.3
# ...     ...
# 1073  179.8
# 1074  173.5
# 1075  176.0
# 1076  176.0
# 1077  170.2
#
# [1078 rows x 1 columns]

# %% [markdown]
# `sons_df`는 비록 하나의 열로 구성되었다 하더라도 시리즈가 아닌 데이터프레임 객체다.
# 자료형을 확인하라.

# %% [markdown]
# 답:

# %%
type(sons_df)
# Out:
# pandas.DataFrame

# %% [markdown]
# ## 데이터프레임 속성

# %% [markdown]
# 사전 객체가 다음과 같이 주어졌다.

# %%
abcd_dict = {"A": 1.0,
             "B": pd.Series(range(5), index=list(range(5)), dtype="float32"),
             "C": np.array([3] * 5, dtype="int32"),
             "D": ["test", "train", "test", "train", "test"],}

# %% [markdown]
# 동일한 길이의 시퀀스(리스트, 어레이, 시리즈) 또는 스칼라를 값으로 갖는 사전이므로 데이터프레임 생성에 활용될 수 있으며,
# 각각의 키가 열 인덱스로 사용된다.

# %%
abcd_df = pd.DataFrame(abcd_dict)
abcd_df
# Out:
#      A    B  C      D
# 0  1.0  0.0  3   test
# 1  1.0  1.0  3  train
# 2  1.0  2.0  3   test
# 3  1.0  3.0  3  train
# 4  1.0  4.0  3   test

# %% [markdown]
# **`dtypes` 속성**

# %% [markdown]
# 데이터프레임은 넘파이 어레이와는 다르게 각 열의 자료형이 다른 것을 허용한다.
# 다만, 열 별 자료형은 하나로 통일되어야 한다.
# 데이터프레임 `abcd_df`의 열별 자료형은 다음과 같이 확인한다.

# %%
abcd_df.dtypes
# Out:
# A    float64
# B    float32
# C      int32
# D        str
# dtype: object

# %% [markdown]
# **`shape` 속성**

# %% [markdown]
# `shape` 속성은 데이터프레임의 행과 열의 개수를 튜플로 저장한다.
# `abcd_df` 변수가 가리키는 데이터프레임은 5개의 행과 4개의 열로 구성된다.

# %%
abcd_df.shape
# Out:
# (5, 4)

# %% [markdown]
# **`columns` 속성**

# %% [markdown]
# `columns` 속성에 열 이름으로 구성된 `Index` 객체가 저장된다.

# %%
abcd_df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='str')

# %% [markdown]
# `columns` 속성을 이용하여 열의 순서를 변경할 수 있다.
# 아래 코드는 알파벳 역순으로 열을 지정한다.

# %%
dcba_df = pd.DataFrame(abcd_df, columns=['D', 'C', 'B', 'A'])
dcba_df
# Out:
#        D  C    B    A
# 0   test  3  0.0  1.0
# 1  train  3  1.0  1.0
# 2   test  3  2.0  1.0
# 3  train  3  3.0  1.0
# 4   test  3  4.0  1.0

# %% [markdown]
# **`index` 속성**

# %% [markdown]
# 데이터프레임 `abcd_df`의 행 인덱스는 자동 지정되었으므로 `RangeIndex` 객체가 사용되었다.

# %%
abcd_df.index
# Out:
# Index([0, 1, 2, 3, 4], dtype='int64')

# %% [markdown]
# **`name` 특성**

# %% [markdown]
# 데이터프레임은 행 인덱스와 열 인덱스 객체 각각에 대해 `name` 속성을 지정할 수 있다.
# 아래 코드는 행과 열의 이름을 각각 `'품목'`과 `'번호'`로 지정한다.

# %%
abcd_df.columns.name = '품목'
abcd_df.index.name = '번호'
abcd_df
# Out:
# 품목    A    B  C      D
# 번호
# 0   1.0  0.0  3   test
# 1   1.0  1.0  3  train
# 2   1.0  2.0  3   test
# 3   1.0  3.0  3  train
# 4   1.0  4.0  3   test

# %% [markdown]
# 행과 열의 이름이 지정한 대로 확인된다.

# %%
abcd_df.index.name
# Out:
# '번호'

# %%
abcd_df.columns.name
# Out:
# '품목'

# %% [markdown]
# **`values` 속성**

# %% [markdown]
# 데이터프레임의 `values` 속성은 항목만으로 이루어진 2차원 어레이를 가리킨다.
# 열 별 자료형이 다른 경우 `object`로 `dtype`이 지정된다.

# %%
abcd_df.values
# Out:
# array([[1.0, 0.0, 3, 'test'],
#        [1.0, 1.0, 3, 'train'],
#        [1.0, 2.0, 3, 'test'],
#        [1.0, 3.0, 3, 'train'],
#        [1.0, 4.0, 3, 'test']], dtype=object)

# %% [markdown]
# ### 연습문제

# %% [markdown]
# (1) 아래 코드는 피어슨 아버지-아들 키 데이터셋을 데이터프레임으로 불러온다.
# CSV 파일에 헤더를 지정하면 각 열의 라벨로 함께 불러온다.

# %%
pearson_df = pd.read_csv(data_url+"pearson_dataset.csv", header=0)
pearson_df
# Out:
#       Father    Son
# 0      165.1  151.9
# 1      160.8  160.5
# 2      165.1  160.8
# 3      167.1  159.5
# 4      155.2  163.3
# ...      ...    ...
# 1073   170.2  179.8
# 1074   181.1  173.5
# 1075   182.4  176.0
# 1076   179.6  176.0
# 1077   178.6  170.2
#
# [1078 rows x 2 columns]

# %% [markdown]
# 가.
# `pearson_df`의 행 인덱스 객체, 열 인덱스 객체, 그리고 데이터프레임의 모양(`shape`)을 각각 확인하라.

# %% [markdown]
# 답:

# %% [markdown]
# CSV 파일을 불러올 때 행 인덱스를 별도로 지정하지 않았기에 `RangeIndex` 객체가 사용되며,
# 헤더로 지정된 첫째 행의 값이 열 인덱스로 사용된다.

# %%
pearson_df.index
# Out:
# RangeIndex(start=0, stop=1078, step=1)

# %% [markdown]
# 열 인덱스는 헤더에 포함된 열 이름으로 구성된다.

# %%
pearson_df.columns
# Out:
# Index(['Father', 'Son'], dtype='str')

# %% [markdown]
# 데이터프레임의 모양은 행과 열의 개수로 지정된다.

# %%
pearson_df.shape
# Out:
# (1078, 2)

# %% [markdown]
# 나. `pearson_df`의 열별 자료형(`dtypes`)을 확인하고, 항목만으로 이루어진 넘파이 2차원 어레이를 `values` 속성을 이용하여 추출하라.

# %% [markdown]
# 답:

# %% [markdown]
# 두 열 모두 키(cm) 데이터이므로 `float64` 자료형이다.

# %%
pearson_df.dtypes
# Out:
# Father    float64
# Son       float64
# dtype: object

# %% [markdown]
# `values` 속성은 행과 열 인덱스를 제외한 항목만으로 구성된 넘파이 2차원 어레이를 가리킨다.

# %%
pearson_df.values
# Out:
# array([[165.1, 151.9],
#        [160.8, 160.5],
#        [165.1, 160.8],
#        ...,
#        [182.4, 176. ],
#        [179.6, 176. ],
#        [178.6, 170.2]], shape=(1078, 2))

# %% [markdown]
# (2) 아래 코드는 붓꽃 데이터셋을 데이터프레임으로 불러온다.
# `header=0`으로 굳이 지정하지 않아도 0번 줄을 헤더로 불러온다.
# 다만, 경우에 따라 헤더가 없는 파일이 있으니 조심해야 하며,
# 헤더의 존재 여부를 미리 확인해 두어야 한다.

# %%
iris_df = pd.read_csv(data_url+"iris.csv") # header=0이 기본값
iris_df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 가. 붓꽃 데이터셋의 열별 자료형을 확인하라.

# %% [markdown]
# 답:

# %% [markdown]
# 데이터프레임의 `dtypes` 속성을 확인하면 된다.

# %%
iris_df.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety             str
# dtype: object

# %% [markdown]
# 나. `iris_df`의 모양(`shape`)과 열 인덱스 객체(`columns`)를 각각 확인하라.

# %% [markdown]
# 답:

# %% [markdown]
# 데이터프레임의 모양은 `shape` 속성에 저장된다.

# %%
iris_df.shape
# Out:
# (150, 5)

# %% [markdown]
# 데이터프레임의 열 인덱스는 `columns` 속성에 저장된다.

# %%
iris_df.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='str')

# %% [markdown]
# 다. `iris_df`의 항목만으로 이루어진 넘파이 2차원 어레이를 `values` 속성을 이용하여 추출하라.
# 단, 처음 10개의 행만 출력한다.

# %% [markdown]
# 답:

# %% [markdown]
# `values` 속성 결과에 대해 슬라이싱을 적용한다.
# 이때, 속성 확인이 슬라이싱보다 우선순위가 높기에 굳이 괄호를 사용하지 않아도 된다.

# %%
iris_df.values[:10]
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'Setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'Setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'Setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'Setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'Setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'Setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'Setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'Setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'Setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'Setosa']], dtype=object)

# %% [markdown]
# 라. `values` 속성에 저장된 어레이의 자료형(`dtype`)을 확인하라.

# %% [markdown]
# 답:

# %% [markdown]
# `variety` 열이 문자열이므로 넘파이 어레이는 모든 항목을 `object` 자료형으로 통일한다.

# %%
iris_df.values.dtype
# Out:
# dtype('O')

# %% [markdown]
# ## 데이터프레임 인덱싱

# %% [markdown]
# 데이터프레임의 인덱싱과 슬라이싱은 모두 행과 열에 대해 서로 독립적으로 작동한다.
# 행과 열 각각에 대한 인덱싱과 슬라이싱의 작동방식은 시리즈의 인덱싱, 슬라이싱 방식과
# 매우 유사하다.
# 또한 넘파이 2차원 어레이의 경우처럼 행과 열에 대한 인덱싱, 슬라이싱을
# 조합할 수도 있다.
#
# 설명을 위해 `fruits3`이 가리키는 데이터프레임을 활용한다.

# %%
fruits_array = np.array([[4, 5, 2],
                         [5, 4, 3],
                         [6, 3, 5],
                         [3, 0, 2],
                         [1, 2, 7]])

fruits3 = pd.DataFrame(fruits_array,
                       columns=['Mango', 'Apple', 'Banana'],
                       index=['A', 'B', 'C', 'D', 'E'])

fruits3
# Out:
#    Mango  Apple  Banana
# A      4      5       2
# B      5      4       3
# C      6      3       5
# D      3      0       2
# E      1      2       7

# %% [markdown]
# ### 열 인덱싱

# %% [markdown]
# 열 인덱싱은 세 가지 방식으로 지원된다.
#
# - `[]` 활용
# - `.loc[]` 활용
# - `.iloc[]` 활용

# %% [markdown]
# **`[]` 활용**
#
# 시리즈의 경우와는 다르게 대괄호만 사용하는 인덱싱은 열 라벨에 대해 실행된다.
# 예를 들어 아래 코드는 망고 열만 시리즈로 추출한다.

# %%
fruits3['Mango']
# Out:
# A    4
# B    5
# C    6
# D    3
# E    1
# Name: Mango, dtype: int64

# %% [markdown]
# 대괄호를 사용하지 않으면서 열의 이름을 마치 데이터프레임 객체의 속성인 것처럼 활용할 수 있다.
# 아래 코드는 `Banana` 열을 시리즈로 추출한다.

# %%
fruits3.Banana
# Out:
# A    2
# B    3
# C    5
# D    2
# E    7
# Name: Banana, dtype: int64

# %% [markdown]
# **`.loc[]` 활용**
#
# 넘파이 2차원 어레이의 경우처럼 쉼표를 기준으로 행과, 열에 대한 인덱싱 또는 슬라이싱을 지정한다.
# 예를 들어 아래 코드는 사과 열만 시리즈로 추출하기 위해, 행에 대해서는 행 전체를 가리키는
# 슬라이싱 기호 (`:`)를 쉼표 왼쪽에 위치시켜야 한다.

# %%
fruits3.loc[:, 'Apple']
# Out:
# A    5
# B    4
# C    3
# D    0
# E    2
# Name: Apple, dtype: int64

# %% [markdown]
# **`.iloc[]` 활용**
#
# 정수 인덱스로 열 인덱싱을 적용할 수 있다.
# 예를 들어, 사과는 1번 인덱스 열이기에 다음과 같이 추출한다.
# 행 전체 대상 슬라이싱이 여기서도 필요함에 주의한다.

# %%
fruits3.iloc[:, 1]
# Out:
# A    5
# B    4
# C    3
# D    0
# E    2
# Name: Apple, dtype: int64

# %% [markdown]
# ### 데이터프레임 열 추가/업데이트

# %% [markdown]
# 열 라벨 인덱싱을 이용하여 새로운 특성을 추가할 수 있다.
# 아래 코드는 패션프루트라는 특이한 이름의 과일 목록을 담은
# `'Passion fruit'` 열을 새롭게 추가하면서
# 각 행의 값을 7로 지정한다.
# 넘파이 어레이에서 다룬 브로드캐스팅이 작동함에 주의한다.

# %%
fruits3['Passion fruit'] = 7
fruits3
# Out:
#    Mango  Apple  Banana  Passion fruit
# A      4      5       2              7
# B      5      4       3              7
# C      6      3       5              7
# D      3      0       2              7
# E      1      2       7              7

# %% [markdown]
# 동일한 방식으로 열의 항목을 업데이트 할 수도 있다.
# 아래 코드는 패현프루트 열의 각 행의 값을 5로 업데이트 한다.

# %%
fruits3['Passion fruit'] = 5
fruits3
# Out:
#    Mango  Apple  Banana  Passion fruit
# A      4      5       2              5
# B      5      4       3              5
# C      6      3       5              5
# D      3      0       2              5
# E      1      2       7              5

# %% [markdown]
# 행 전체의 길이와 동일한 리스트 또는 어레이를 이용하여 새로운 열을 추가하거나
# 기존에 있던 열의 항목을 업데이트 할 수 있다.
# 아래 코드는 포도 열을 추가하면서 길이가 5인 레인지 객체를 항목들의 값으로 지정하였다.

# %%
fruits3['Grape'] = range(10, 15)
fruits3
# Out:
#    Mango  Apple  Banana  Passion fruit  Grape
# A      4      5       2              5     10
# B      5      4       3              5     11
# C      6      3       5              5     12
# D      3      0       2              5     13
# E      1      2       7              5     14

# %% [markdown]
# 아래 코드는 패션프루트 열을 길이가 5인 리스트를 이용하여 업데이트 한다.

# %%
fruits3['Passion fruit'] = [5, 4, 3, 2, 1]
fruits3
# Out:
#    Mango  Apple  Banana  Passion fruit  Grape
# A      4      5       2              5     10
# B      5      4       3              4     11
# C      6      3       5              3     12
# D      3      0       2              2     13
# E      1      2       7              1     14

# %% [markdown]
# 참고로 `'Passion fruit'` 열을 인덱싱하려면 반드시 대괄호 방식을 사용해야 한다.
# 이유는 공백이 포함되어있기 때문에 변수처럼 취급될 수 없기 때문이다.

# %%
fruits3.Passion fruit
# Out:
#   Cell In[61], line 1
#     fruits3.Passion fruit
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# 이런 경우엔 무조건 대괄호를 사용해야 한다.

# %%
fruits3['Passion fruit']
# Out:
# A    5
# B    4
# C    3
# D    2
# E    1
# Name: Passion fruit, dtype: int64

# %% [markdown]
# ### 행 인덱싱

# %% [markdown]
# 행 인덱싱은 두 가지 방식으로 지원된다.
#
# - `.loc[]` 활용
# - `.iloc[]` 활용
#
# 즉, 대괄호만 사용하는 행 인덱싱은 지원되지 않는다.
# 데이터프레임 `fruits3`를 계속 활용하여 설명한다.

# %%
fruits3
# Out:
#    Mango  Apple  Banana  Passion fruit  Grape
# A      4      5       2              5     10
# B      5      4       3              4     11
# C      6      3       5              3     12
# D      3      0       2              2     13
# E      1      2       7              1     14

# %% [markdown]
# **`.loc[]` 활용**
#
# 아래 코드는 `'A'` 라벨 행을 시리즈 객체로 추출한다.
# 생성된 시리즈의 행 인덱스는 데이터프레임의 열 인덱스가 사용된다.

# %%
fruits3.loc['A']
# Out:
# Mango             4
# Apple             5
# Banana            2
# Passion fruit     5
# Grape            10
# Name: A, dtype: int64

# %% [markdown]
# **`.iloc[]` 활용**
#
# 정수 인덱스로 행 인덱싱을 적용할 수 있다.
# 예를 들어, `'C'` 라벨 행은 2번 인덱스 행이기에 다음과 같이 추출한다.

# %%
fruits3.iloc[2]
# Out:
# Mango             6
# Apple             3
# Banana            5
# Passion fruit     3
# Grape            12
# Name: C, dtype: int64

# %% [markdown]
# ### 팬시 인덱싱

# %% [markdown]
# 열 인덱스 또는 행 인덱스로 구성된 리스트를 인덱싱에 활용하는 기법이
# **팬시 인덱싱**<font size='2'>fancy indexing</font>이다.
# 이때, 라벨 또는 정수로만 구성된 리스트를 지정해야 하며,
# 결과는 지정된 순서의 열 또는 행으로 구성된 데이터프레임 객체다.

# %% [markdown]
# **열 팬시 인덱싱**
#
# 열 인덱싱처럼 세 가지 방식이 모두 지원된다.
# 예를 들어 망고와 바나나 열로 구성된 데이터프레임을 생성해본다.
#
# 아래 세 코드는 모두 망고, 바나타, 패션프루트 열만으로 구성된 데이터프레임을
# 추출한다.

# %%
fruits3[['Mango', 'Banana', 'Passion fruit']]
# Out:
#    Mango  Banana  Passion fruit
# A      4       2              5
# B      5       3              4
# C      6       5              3
# D      3       2              2
# E      1       7              1

# %%
fruits3.loc[:, ['Mango', 'Banana', 'Passion fruit']]
# Out:
#    Mango  Banana  Passion fruit
# A      4       2              5
# B      5       3              4
# C      6       5              3
# D      3       2              2
# E      1       7              1

# %%
fruits3.iloc[:, [0, 2, 3]]
# Out:
#    Mango  Banana  Passion fruit
# A      4       2              5
# B      5       3              4
# C      6       5              3
# D      3       2              2
# E      1       7              1

# %% [markdown]
# 길이가 1인 인덱스 리스트를 사용해도 결과는 시리즈가 아닌 데이터프레임이다.

# %%
fruits3[['Apple']]
# Out:
#    Apple
# A      5
# B      4
# C      3
# D      0
# E      2

# %%
type(fruits3[['Apple']])
# Out:
# pandas.DataFrame

# %% [markdown]
# 일반 인덱싱의 결과는 시리즈임에 주의한다.

# %%
fruits3['Apple']
# Out:
# A    5
# B    4
# C    3
# D    0
# E    2
# Name: Apple, dtype: int64

# %%
type(fruits3['Apple'])
# Out:
# pandas.Series

# %% [markdown]
# **행 팬시 인덱싱**
#
# 행 인덱싱처럼 두 가지 방식이 지원된다.
# 예를 들어 `'B'`, `'D'`, `'E'` 세 라벨 인덱스의 행으로 구성된 데이터프레임을 생성해본다.

# %%
fruits3.loc[['B', 'D', 'E']]
# Out:
#    Mango  Apple  Banana  Passion fruit  Grape
# B      5      4       3              4     11
# D      3      0       2              2     13
# E      1      2       7              1     14

# %%
fruits3.iloc[[1, 3, 4]]
# Out:
#    Mango  Apple  Banana  Passion fruit  Grape
# B      5      4       3              4     11
# D      3      0       2              2     13
# E      1      2       7              1     14

# %% [markdown]
# 길이가 1인 인덱스 리스트를 사용해도 결과는 시리즈가 아닌 데이터프레임이다.

# %%
fruits3.loc[['A']]
# Out:
#    Mango  Apple  Banana  Passion fruit  Grape
# A      4      5       2              5     10

# %%
fruits3.iloc[[0]]
# Out:
#    Mango  Apple  Banana  Passion fruit  Grape
# A      4      5       2              5     10

# %% [markdown]
# ### 연습문제

# %% [markdown]
# (1) 아래 코드는 (6, 4) 모양의 데이터프레임을 생성한다.
#
# - 행 인덱스: `dates` 변수가 가리키는 `DatetimeIndex` 객체
# - 항목: `np.arange()` 함수 활용 후 어레이 모양 변경
# - 열 인덱스: `['A', 'B', 'C', 'D']` 지정

# %%
dates = pd.date_range(start="20260301", periods=6, freq="D")
df = pd.DataFrame(np.arange(24).reshape(6, 4), index=dates, columns=list("ABCD"))

df
# Out:
#              A   B   C   D
# 2026-03-01   0   1   2   3
# 2026-03-02   4   5   6   7
# 2026-03-03   8   9  10  11
# 2026-03-04  12  13  14  15
# 2026-03-05  16  17  18  19
# 2026-03-06  20  21  22  23

# %% [markdown]
# 가. 가능한 모든 방법으로 `'A'` 열만을 추출하여 시리즈를 생성하라.

# %% [markdown]
# 답:

# %% [markdown]
# 열 라벨을 이용한 인덱싱을 적용한다.

# %%
df["A"]
# Out:
# 2026-03-01     0
# 2026-03-02     4
# 2026-03-03     8
# 2026-03-04    12
# 2026-03-05    16
# 2026-03-06    20
# Freq: D, Name: A, dtype: int64

# %% [markdown]
# 열 라벨을 객체의 속성처럼 이용하는 방식도 가능하다.

# %%
df.A
# Out:
# 2026-03-01     0
# 2026-03-02     4
# 2026-03-03     8
# 2026-03-04    12
# 2026-03-05    16
# 2026-03-06    20
# Freq: D, Name: A, dtype: int64

# %% [markdown]
# `.loc[]`과 `.iloc[]` 형식도 활용할 수 있다.

# %%
df.loc[:, "A"]
# Out:
# 2026-03-01     0
# 2026-03-02     4
# 2026-03-03     8
# 2026-03-04    12
# 2026-03-05    16
# 2026-03-06    20
# Freq: D, Name: A, dtype: int64

# %%
df.iloc[:, 0]
# Out:
# 2026-03-01     0
# 2026-03-02     4
# 2026-03-03     8
# 2026-03-04    12
# 2026-03-05    16
# 2026-03-06    20
# Freq: D, Name: A, dtype: int64

# %% [markdown]
# 나. 첫번째 날짜, 즉 2026년 3월 1일의 데이터를 확인하는 한 줄 표현식을 작성하라.
# 단, `.loc[]` 객체와 `dates` 변수를 이용해야 한다.

# %% [markdown]
# 답:

# %% [markdown]
# 2026년 3월 1일은 `dates` 객체의 0번 인덱스의 값이며,
# 다음과 같이 `.loc[]`과 함께 활용하면 된다.

# %%
df.loc[dates[0]]
# Out:
# A    0
# B    1
# C    2
# D    3
# Name: 2026-03-01 00:00:00, dtype: int64

# %% [markdown]
# 정수 인덱스 0을 활용해도 된다.

# %%
df.iloc[0]
# Out:
# A    0
# B    1
# C    2
# D    3
# Name: 2026-03-01 00:00:00, dtype: int64

# %% [markdown]
# 다. `.loc[]` 객체를 이용해 `'A'`와 `'B'` 두 열만 추출하는 한 줄 표현식을 작성하라.

# %% [markdown]
# 답:

# %% [markdown]
# 열에 대한 팬시 인덱싱을 적용하면 된다.

# %%
df.loc[:, ["A", "B"]]
# Out:
#              A   B
# 2026-03-01   0   1
# 2026-03-02   4   5
# 2026-03-03   8   9
# 2026-03-04  12  13
# 2026-03-05  16  17
# 2026-03-06  20  21

# %% [markdown]
# 정수 인덱스를 활용해도 된다.

# %%
df.iloc[:, [0, 1]]
# Out:
#              A   B
# 2026-03-01   0   1
# 2026-03-02   4   5
# 2026-03-03   8   9
# 2026-03-04  12  13
# 2026-03-05  16  17
# 2026-03-06  20  21

# %% [markdown]
# 라. `.iloc[]` 객체를 이용해 3번 행만 추출하는 한 줄 표현식을 작성하시오.

# %% [markdown]
# 답:

# %%
df.iloc[3]
# Out:
# A    12
# B    13
# C    14
# D    15
# Name: 2026-03-04 00:00:00, dtype: int64

# %% [markdown]
# 마. 2026년 3월 1일, 3일, 6일 행의 데이터만 추출하라.

# %% [markdown]
# 답:

# %% [markdown]
# 2026년 3월 1일, 3일, 6일은 0번, 2번, 5번 행의 라벨이기에
# 다음과 같이 행 팬시 인덱싱을 실행한다.

# %%
df.iloc[[0, 2, 5]]
# Out:
#              A   B   C   D
# 2026-03-01   0   1   2   3
# 2026-03-03   8   9  10  11
# 2026-03-06  20  21  22  23

# %% [markdown]
# 날짜 라벨로 구성된 리스트를 직접 이용할 수도 있다.

# %%
df.loc[['2026-03-01', '2026-03-03', '2026-03-06']]
# Out:
#              A   B   C   D
# 2026-03-01   0   1   2   3
# 2026-03-03   8   9  10  11
# 2026-03-06  20  21  22  23

# %% [markdown]
# 날짜를 적는 것 보다는 `dates` 객체에 인덱싱을 적용하는 게 실수를 줄인다.

# %%
df.loc[[dates[0], dates[2], dates[5]]]
# Out:
#              A   B   C   D
# 2026-03-01   0   1   2   3
# 2026-03-03   8   9  10  11
# 2026-03-06  20  21  22  23

# %% [markdown]
# `dates`가 가리키는 `DatetimeIndex` 객체에 팬시 인덱싱을 적용한 결과를 이용하여
# 데이터프레임에 대한 행 팬시 인덱싱을 적용할 수도 있다.

# %%
df.loc[dates[[0, 2, 5]]]
# Out:
#              A   B   C   D
# 2026-03-01   0   1   2   3
# 2026-03-03   8   9  10  11
# 2026-03-06  20  21  22  23

# %% [markdown]
# 바. `.iloc[]` 객체를 이용해 홀수 행만 추출하는 한 줄 표현식을 작성하시오.

# %% [markdown]
# 답:

# %%
df.iloc[1::2, :]
# Out:
#              A   B   C   D
# 2026-03-02   4   5   6   7
# 2026-03-04  12  13  14  15
# 2026-03-06  20  21  22  23

# %% [markdown]
# 열 전체를 대상으로 하는 슬라이싱은 생략해도 된다.

# %%
df.iloc[1::2]
# Out:
#              A   B   C   D
# 2026-03-02   4   5   6   7
# 2026-03-04  12  13  14  15
# 2026-03-06  20  21  22  23

# %% [markdown]
# 사. `.iloc[]` 객체를 이용해 1번, 2번 열만 추출하는 한 줄 표현식을 작성하시오.

# %% [markdown]
# 답:

# %% [markdown]
# 0번 축에 대해서는 모든 행을 가져오라는 슬라이싱을 명시해야 한다.

# %%
df.iloc[:, 1:3]
# Out:
#              B   C
# 2026-03-01   1   2
# 2026-03-02   5   6
# 2026-03-03   9  10
# 2026-03-04  13  14
# 2026-03-05  17  18
# 2026-03-06  21  22

# %% [markdown]
# (2) 아래 코드는 붓꽃 데이터셋을 데이터프레임으로 불러온다.

# %%
iris_df = pd.read_csv(data_url+"iris.csv")
iris_df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 가. 가능한 모든 방법으로 `'variety'` 열만 시리즈로 추출하라.

# %% [markdown]
# 답:

# %% [markdown]
# 대괄호 인덱싱, 속성 방식, `.loc[]`, `.iloc[]` 네 가지 방법 모두 가능하다.

# %%
iris_df['variety']
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: variety, Length: 150, dtype: str

# %%
iris_df.variety
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: variety, Length: 150, dtype: str

# %%
iris_df.loc[:, 'variety']
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: variety, Length: 150, dtype: str

# %%
iris_df.iloc[:, 4]
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: variety, Length: 150, dtype: str

# %% [markdown]
# 나. `.iloc[]` 객체를 이용하여 0번 행의 데이터를 시리즈로 추출하라.

# %% [markdown]
# 답:

# %%
iris_df.iloc[0]
# Out:
# sepal.length       5.1
# sepal.width        3.5
# petal.length       1.4
# petal.width        0.2
# variety         Setosa
# Name: 0, dtype: object

# %% [markdown]
# 다. `'sepal.length'`와 `'petal.length'` 두 열만 추출하는 한 줄 표현식을 작성하라.
# 단, `.loc[]` 객체와 팬시 인덱싱을 활용한다.

# %% [markdown]
# 답:

# %% [markdown]
# 열에 대한 팬시 인덱싱을 적용하면 된다.

# %%
iris_df.loc[:, ['sepal.length', 'petal.length']]
# Out:
#      sepal.length  petal.length
# 0             5.1           1.4
# 1             4.9           1.4
# 2             4.7           1.3
# 3             4.6           1.5
# 4             5.0           1.4
# ..            ...           ...
# 145           6.7           5.2
# 146           6.3           5.0
# 147           6.5           5.2
# 148           6.2           5.4
# 149           5.9           5.1
#
# [150 rows x 2 columns]

# %% [markdown]
# 라. `.iloc[]` 객체를 이용하여 0번, 50번, 100번 행의 데이터만 추출하라.

# %% [markdown]
# 답:

# %% [markdown]
# 행 팬시 인덱싱을 적용한다.
# 각 인덱스는 붓꽃 세 품종(setosa, versicolor, virginica)의 첫 번째 데이터에 해당한다.

# %%
iris_df.iloc[[0, 50, 100]]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 0             5.1          3.5           1.4          0.2      Setosa
# 50            7.0          3.2           4.7          1.4  Versicolor
# 100           6.3          3.3           6.0          2.5   Virginica

# %% [markdown]
# ## 데이터프레임 슬라이싱

# %% [markdown]
# `.loc[]` 과 `.iloc[]`을 행과 열에 동시에 적용할 수 있으며,
# 넘파이 2차원 어레이에 대한 인덱싱/슬라이싱이 작동하는 방식과 거의 동일하다.
# 설명을 위해 계속해서 `fruits3`가 가리키는 데이터프레임을 이용한다.

# %%
fruits3
# Out:
#    Mango  Apple  Banana  Passion fruit  Grape
# A      4      5       2              5     10
# B      5      4       3              4     11
# C      6      3       5              3     12
# D      3      0       2              2     13
# E      1      2       7              1     14

# %% [markdown]
# ### 열 슬라이싱

# %% [markdown]
# 열에 대해서만 슬라이싱을 적용하려면 행을 전체로 지정한다.
# 아래 코드는 전체 행을 대상으로 2번 인덱스열 이전까지 추출한다.

# %%
fruits3.iloc[:, :2]
# Out:
#    Mango  Apple
# A      4      5
# B      5      4
# C      6      3
# D      3      0
# E      1      2

# %% [markdown]
# 정수 인덱스가 아닌 열 라벨을 이용한 슬라이싱은 `.loc[]`함수를 써야하고, 지정한 구간의 끝도 포함됨에 유의한다.

# %%
fruits3.loc[:, :'Banana']
# Out:
#    Mango  Apple  Banana
# A      4      5       2
# B      5      4       3
# C      6      3       5
# D      3      0       2
# E      1      2       7

# %% [markdown]
# ### 행 슬라이싱

# %% [markdown]
# 행에 대해서만 슬라이싱을 적용하려면 열을 전체로 지정한다.
# 아래 코드는 2번 인덱스 행부터 모두 가져온다.

# %%
fruits3.iloc[2:, :]
# Out:
#    Mango  Apple  Banana  Passion fruit  Grape
# C      6      3       5              3     12
# D      3      0       2              2     13
# E      1      2       7              1     14

# %% [markdown]
# 열 슬라이싱은 지정하지 않아도 된다.

# %%
fruits3.iloc[2:]
# Out:
#    Mango  Apple  Banana  Passion fruit  Grape
# C      6      3       5              3     12
# D      3      0       2              2     13
# E      1      2       7              1     14

# %% [markdown]
# 지정된 열 라벨 인덱스를 활용할 수도 있다.

# %%
fruits3.loc['C':, :]
# Out:
#    Mango  Apple  Banana  Passion fruit  Grape
# C      6      3       5              3     12
# D      3      0       2              2     13
# E      1      2       7              1     14

# %%
fruits3.loc['C':]
# Out:
#    Mango  Apple  Banana  Passion fruit  Grape
# C      6      3       5              3     12
# D      3      0       2              2     13
# E      1      2       7              1     14

# %% [markdown]
# 라벨을 이용할 경우 슬라이싱의 끝도 포함하기에 다음도 가능하다.

# %%
fruits3.loc['C':'E']
# Out:
#    Mango  Apple  Banana  Passion fruit  Grape
# C      6      3       5              3     12
# D      3      0       2              2     13
# E      1      2       7              1     14

# %% [markdown]
# **스텝 활용**

# %% [markdown]
# 정수 인덱스를 활용하는 경우
# 스텝<font size='2'>step</font>도 사용할 수 있다.
# 아래 코드는 짝수 인덱스 열 또는 행에 속한 항목만 추출한다.

# %%
fruits3.iloc[:, ::2]
# Out:
#    Mango  Banana  Grape
# A      4       2     10
# B      5       3     11
# C      6       5     12
# D      3       2     13
# E      1       7     14

# %%
fruits3.iloc[::2]
# Out:
#    Mango  Apple  Banana  Passion fruit  Grape
# A      4      5       2              5     10
# C      6      3       5              3     12
# E      1      2       7              1     14

# %% [markdown]
# ### 인덱싱과 슬라이싱의 조합

# %% [markdown]
# 인덱싱과 슬라이싱의 어떤 조합도 행과 열에 대해 적용할 수 있다.
#
# 아래 코드는 `'C'`라벨 행의 `'Apple'`과 `'Grape'` 열의 항목을 별도의 시리즈로 추출한다.

# %%
fruits3.loc['C', ['Apple', 'Grape']]
# Out:
# Apple     3
# Grape    12
# Name: C, dtype: int64

# %% [markdown]
# 아래 코드는 `'C'` 라벨 행까지의 모든 행에서 `'Banana'` 열의 항목을 시리즈로 추출한다.

# %%
fruits3.loc[:'C', 'Banana']
# Out:
# A    2
# B    3
# C    5
# Name: Banana, dtype: int64

# %% [markdown]
# 아래 코드는 2번 인덱스 행의 1번, 2번 인덱스 열의 항목을 시리즈로 추출한다.

# %%
fruits3.iloc[2, [1, 2]]
# Out:
# Apple     3
# Banana    5
# Name: C, dtype: int64

# %% [markdown]
# 아래 코드는 1번, 2번 인덱스 행의 3번, 0번, 1번 인덱스 열의 항목을 별도의 데이터프레임으로 추출한다.

# %%
fruits3.iloc[[1, 2], [3, 0, 1]]
# Out:
#    Passion fruit  Mango  Apple
# B              4      5      4
# C              3      6      3

# %% [markdown]
# 아래 코드는 `'D'` 라벨 행까지의 모든 행에서 `'Banana'` 열부터 이후의 모든 열의 항목을 데이터프레임으로 추출한다.

# %%
fruits3.loc[:'D', 'Banana':]
# Out:
#    Banana  Passion fruit  Grape
# A       2              5     10
# B       3              4     11
# C       5              3     12
# D       2              2     13

# %% [markdown]
# ### 연습문제

# %% [markdown]
# (1) 아래 코드는 (6, 4) 모양의 데이터프레임을 생성한다.
#
# - 행 인덱스: `dates` 변수가 가리키는 `DatetimeIndex` 객체
# - 항목: `np.arange()` 함수 활용 후 어레이 모양 변경
# - 열 인덱스: `['A', 'B', 'C', 'D']` 지정

# %%
dates = pd.date_range(start="20260301", periods=6, freq="D")
df = pd.DataFrame(np.arange(24).reshape(6, 4), index=dates, columns=list("ABCD"))

df
# Out:
#              A   B   C   D
# 2026-03-01   0   1   2   3
# 2026-03-02   4   5   6   7
# 2026-03-03   8   9  10  11
# 2026-03-04  12  13  14  15
# 2026-03-05  16  17  18  19
# 2026-03-06  20  21  22  23

# %% [markdown]
# 가. 가능한 모든 방법으로 0번 행부터 2번 행까지 포함하는 데이터프레임을 생성하라.

# %% [markdown]
# 답:

# %% [markdown]
# 행 인덱스가 날짜 형식이기에 가장 간단한 방식은 정수 인덱스를 활용한 슬라이싱이다.

# %%
df.iloc[0:3]
# Out:
#             A  B   C   D
# 2026-03-01  0  1   2   3
# 2026-03-02  4  5   6   7
# 2026-03-03  8  9  10  11

# %% [markdown]
# 슬라이싱 구간의 시작이 0번 인덱스인 경우 0은 생략해도 된다.

# %%
df.iloc[:3]
# Out:
#             A  B   C   D
# 2026-03-01  0  1   2   3
# 2026-03-02  4  5   6   7
# 2026-03-03  8  9  10  11

# %% [markdown]
# 날짜를 정확히 적어야 하는 수고가 필요하지만 라벨 인덱스를 활용하여 슬라이싱을 진행할 수도 있다.
# 위치 인덱스 방식과는 달리 구간의 마지막 라벨도 포함된다.

# %%
df.loc["2026-03-01":"2026-03-03"]
# Out:
#             A  B   C   D
# 2026-03-01  0  1   2   3
# 2026-03-02  4  5   6   7
# 2026-03-03  8  9  10  11

# %% [markdown]
# 나. `.loc[]` 객체를 이용하여 2026년 3월 2일부터 3월 4일까지를 대상으로 `A`, `B` 두 열만 추출하는 한 줄 표현식을 작성하시오.

# %% [markdown]
# 답:

# %%
df.loc["20260302":"20260304", ["A", "B"]]
# Out:
#              A   B
# 2026-03-02   4   5
# 2026-03-03   8   9
# 2026-03-04  12  13

# %% [markdown]
# 다. `.loc[]` 객체를 이용하여 2026년 3월 2일의 `A`, `B` 두 열만 추출하는 한 줄 표현식을 작성하시오.

# %% [markdown]
# 답:

# %%
df.loc["20260302", ["A", "B"]]
# Out:
# A    4
# B    5
# Name: 2026-03-02 00:00:00, dtype: int64

# %% [markdown]
# 라. `.loc[]` 객체와 `dates` 변수를 이용해 2026년 3월 1일의 `A` 열만 추출하는 한 줄 표현식을 작성하시오.

# %% [markdown]
# 답:

# %%
df.loc[dates[0], "A"]
# Out:
# np.int64(0)

# %% [markdown]
# 마.  `.iloc[]` 객체를 이용해 3번부터 4번 인덱스 행을 대상으로 0번, 1번 인덱스의 열만 추출하는 한 줄 표현식을 작성하시오.

# %% [markdown]
# 답:

# %%
df.iloc[3:5, 0:2]
# Out:
#              A   B
# 2026-03-04  12  13
# 2026-03-05  16  17

# %% [markdown]
# 바. 아래 두 리스트에 포함된 행과 열만 순서대로 추출하는 한 줄 표현식을 작성하시오.
# 단, `.iloc[]` 객체와 팬시 인덱싱을 활용한다.
#
# - 행: `[1, 2, 4]`
# - 열: `[0, 2, 3, 1]`

# %% [markdown]
# 답:

# %%
df.iloc[[1, 2, 4], [0, 2, 3, 1]]
# Out:
#              A   C   D   B
# 2026-03-02   4   6   7   5
# 2026-03-03   8  10  11   9
# 2026-03-05  16  18  19  17

# %% [markdown]
# (2) 행 인덱스가 `RangeIndex`인 경우 라벨이 정수이기 때문에
# `.loc[]`와 `.iloc[]` 모두 적용할 수 있지만 슬라이싱의 경우 결과가 다를 수 있다.
#
# 아래 코드는 `RangeIndex`를 행 인덱스로 갖는 간단한 데이터프레임을 생성한다.

# %%
sample_df = pd.DataFrame({"X": range(10), "Y": range(10, 20)})
sample_df
# Out:
#    X   Y
# 0  0  10
# 1  1  11
# 2  2  12
# 3  3  13
# 4  4  14
# 5  5  15
# 6  6  16
# 7  7  17
# 8  8  18
# 9  9  19

# %% [markdown]
# `.iloc[:4]`와 `.loc[:4]`를 각각 적용하고 결과의 차이점을 확인하라.

# %% [markdown]
# 답:

# %% [markdown]
# `.iloc[:4]`는 위치 기반이므로 0번부터 3번 위치까지 4개의 행을 추출한다.

# %%
sample_df.iloc[:4]
# Out:
#    X   Y
# 0  0  10
# 1  1  11
# 2  2  12
# 3  3  13

# %% [markdown]
# `.loc[:4]`는 라벨 기반이므로 라벨 0부터 라벨 4까지를 **모두 포함**하여 5개의 행을 추출한다.

# %%
sample_df.loc[:4]
# Out:
#    X   Y
# 0  0  10
# 1  1  11
# 2  2  12
# 3  3  13
# 4  4  14

# %% [markdown]
# `RangeIndex`의 경우 라벨과 위치 인덱스가 동일한 정수처럼 보이지만,
# `.loc[]`은 구간의 끝을 포함하고 `.iloc[]`은 포함하지 않기 때문에 결과가 다를 수 있다.
# 따라서 `RangeIndex`를 사용하는 데이터프레임에 슬라이싱을 적용할 때
# `.loc[]`과 `.iloc[]`의 차이에 특히 주의해야 한다.

# %% [markdown]
# (3) 아래 코드는 붓꽃 데이터셋을 데이터프레임으로 불러온다.

# %%
iris_df = pd.read_csv(data_url+"iris.csv")
iris_df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 가. `.iloc[]` 객체를 이용하여 처음 10개 행만 추출하는 한 줄 표현식을 작성하라.

# %% [markdown]
# 답:

# %% [markdown]
# 행 슬라이싱을 적용한다. 슬라이싱 구간의 시작이 0번 인덱스이므로 생략할 수 있다.

# %%
iris_df.iloc[:10]
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa
# 8           4.4          2.9           1.4          0.2  Setosa
# 9           4.9          3.1           1.5          0.1  Setosa

# %% [markdown]
# 나. `.iloc[]` 객체를 이용하여 50번 행의 1번부터 3번 인덱스 열까지의 항목을 시리즈로 추출하라.

# %% [markdown]
# 답:

# %% [markdown]
# 행에 대해서는 인덱싱을, 열에 대해서는 슬라이싱을 조합한다.

# %%
iris_df.iloc[50, 1:4]
# Out:
# sepal.width     3.2
# petal.length    4.7
# petal.width     1.4
# Name: 50, dtype: object

# %% [markdown]
# 다. `.loc[]` 객체를 이용하여 처음 5개 행에서 `'sepal.length'`부터 `'petal.width'`까지의 열만 추출하라.

# %% [markdown]
# 답:

# %% [markdown]
# `.loc[]`은 라벨 기반이므로 행과 열 모두 라벨 슬라이싱을 적용한다.
# `.loc[]`의 슬라이싱은 구간의 끝을 포함함에 주의한다.

# %%
iris_df.loc[:4, 'sepal.length':'petal.width']
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %% [markdown]
# 라. `.iloc[]` 객체를 이용하여 짝수 인덱스 행에서 0번, 2번 열만 추출하는 한 줄 표현식을 작성하라.

# %% [markdown]
# 답:

# %% [markdown]
# 행에 대해서는 스텝을 활용한 슬라이싱을, 열에 대해서는 팬시 인덱싱을 조합한다.

# %%
iris_df.iloc[::2, [0, 2]]
# Out:
#      sepal.length  petal.length
# 0             5.1           1.4
# 2             4.7           1.3
# 4             5.0           1.4
# 6             4.6           1.4
# 8             4.4           1.4
# ..            ...           ...
# 140           6.7           5.6
# 142           5.8           5.1
# 144           6.7           5.7
# 146           6.3           5.0
# 148           6.2           5.4
#
# [75 rows x 2 columns]

# %% [markdown]
# 마. `.iloc[]` 객체를 이용하여 마지막 5개 행에서 0번, 2번 열만 추출하는 한 줄 표현식을 작성하라.

# %% [markdown]
# 답:

# %% [markdown]
# 행에 대해서는 슬라이싱을, 열에 대해서는 팬시 인덱싱을 조합한다.

# %%
iris_df.iloc[-5:, [0, 2]]
# Out:
#      sepal.length  petal.length
# 145           6.7           5.2
# 146           6.3           5.0
# 147           6.5           5.2
# 148           6.2           5.4
# 149           5.9           5.1

# %% [markdown]
# 바. `.loc[]` 객체를 이용하여 50번부터 54번 행까지에서 `'petal.length'`와 `'variety'` 열만 추출하라.

# %% [markdown]
# 답:

# %% [markdown]
# 행에 대해서는 라벨 슬라이싱을, 열에 대해서는 팬시 인덱싱을 조합한다.
# 행 인덱스가 `RangeIndex`이므로 정수 라벨을 그대로 사용할 수 있다.

# %%
iris_df.loc[50:54, ['petal.length', 'variety']]
# Out:
#     petal.length     variety
# 50           4.7  Versicolor
# 51           4.5  Versicolor
# 52           4.9  Versicolor
# 53           4.0  Versicolor
# 54           4.6  Versicolor

# %% [markdown]
# 사. `.iloc[]` 객체를 이용하여 0번, 50번, 100번 행에서 2번 인덱스 열부터 끝까지의 항목을 추출하라.

# %% [markdown]
# 답:

# %% [markdown]
# 행에 대해서는 팬시 인덱싱을, 열에 대해서는 슬라이싱을 조합한다.

# %%
iris_df.iloc[[0, 50, 100], 2:]
# Out:
#      petal.length  petal.width     variety
# 0             1.4          0.2      Setosa
# 50            4.7          1.4  Versicolor
# 100           6.0          2.5   Virginica
